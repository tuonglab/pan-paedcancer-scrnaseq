# %% [markdown]
# ### 1. General info of dataset GSE192906
#
# This is the Jupyter Notebook for dataset GSE192906. Its dataset includes a txt count matrix file for each sample. As seen below, in the txt file, each row is a gene and each column is a cell.
#
# Thus, we need to transform each txt file and generate the AnnData object for each sample. In total, there are 10 Peripheral neuroblastic tumor samples.
#
# NB: neuroblastoma
#
# GNB: ganglioneuroblastoma

# %%
# Environment setup
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as anndata
import scipy

# %%
import os
os.getcwd()
# Out:
# '/scratch/user/s4543064/xiaohan-john-project'

# %%
# inspect the first dataset
path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE192906/GSM5768743_NB1_UMI_COUNTS_RAW.txt.gz'
input = pd.read_csv(path, sep='\t', index_col=0) # the first column contains gene names and is the index

print(input.head()) 
print(input.shape) # (33514, 960)
# Out:
#              A1_1_0316_AACGAGGT  A1_1_0316_AAGCACAT  A1_1_0316_ACACCGTG  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              A1_1_0316_ACCTCAGC  A1_1_0316_ACTGTTTG  A1_1_0316_AGCTCCTT  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              A1_1_0316_ATTTAGCG  A1_1_0316_CACACTGA  A1_1_0316_CACAGCAT  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              A1_1_0316_CCTTCAAG  ...  J2_2_0316_GTCATTAG  J2_2_0316_GTTACAGG  \
# MIR1302-2HG                   0  ...                   0                   0
# FAM138A                       0  ...                   0                   0
# OR4F5                         0  ...                   0                   0
# AL627309.1                    0  ...                   0                   0
# AL627309.3                    0  ...                   0                   0
#
#              J2_2_0316_TAACTCCG  J2_2_0316_TCAACGAC  J2_2_0316_TCACCCGA  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              J2_2_0316_TCTCACAC  J2_2_0316_TGGAGCTC  J2_2_0316_TGTACCAA  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              J2_2_0316_TTACGGGT  J2_2_0316_TTCCGTTC
# MIR1302-2HG                   0                   0
# FAM138A                       0                   0
# OR4F5                         0                   0
# AL627309.1                    0                   0
# AL627309.3                    0                   0
#
# [5 rows x 960 columns]
# (33514, 960)

# %% [markdown]
# ### 2. Overall AnnData object of the dataset
#
# <span style="color:red">**IMPORTANT:**</span> transpose the DataFrame.values to match the AnnData.X
#
# 1. `DataFrame.columns`: cell barcodes, which go into `.obs`
# 2. `DataFrame.index`: gene names, `.var`
# 3. `DataFrame.values`: the transpose of the expression matrix, `.X`

# %%
# Load the metadata from the paper's Table S1
age_sex_tissue = {
    'NB1': [0.17, 'female', 'adrenal_ gland'],
    'NB2': [5.08, 'male', 'adrenal_ gland'],
    'NB3': [3.33, 'male', 'retroperitoneum'],
    'NB4': [0.33, 'female', 'posterior_mediastinum'],
    'NB5': [1.58, 'male', 'mediastinum'],
    'GN1': [6.67, 'female', 'adrenal_ gland'],
    'GNB1': [2.33, 'female', 'posterior_mediastinum'],
    'GNB2': [2.42, 'male', 'adrenal_ gland'],
    'GNB3': [2.83, 'male', 'mediastinum'],
    'GNB4': [3, 'male', 'adrenal_ gland'],
}

# %%
from pathlib import Path

# Specify directory paths
data_directory = Path('/scratch/user/s4543064/xiaohan-john-project/data/GSE192906')
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE192906')

# Loop through all files in the directory
for file in data_directory.iterdir():
    gsm, patient_id = file.stem.split('_')[:2]
    sample_name = gsm + '_' + patient_id
    sample_h5ad = sample_name + '_uni.h5ad'

    input = pd.read_csv(file, sep='\t', index_col=0)

    matrix = scipy.sparse.csr_matrix(input.values.T)
    obs_name = pd.DataFrame(index=input.columns)
    var_name = pd.DataFrame(index=input.index)
    var_name.rename_axis('gene_symbols', inplace=True)

    sample = anndata.AnnData(X=matrix, obs=obs_name, var=var_name)

    # Create an observation metric info to store related features
    obs_metrics = pd.DataFrame(index=sample.obs_names) ## Get the identifiers

    if 'GNB' in patient_id:
        obs_metrics['cancer_type'] = 'ganglioneuroblastoma'
    elif 'NB' in patient_id:
        obs_metrics['cancer_type'] = 'neuroblastoma'
    else: # the GN patient
        obs_metrics['cancer_type'] = 'ganglioneuroma' 

    obs_metrics['dataset'] = 'GSE192906'
    obs_metrics['age'] = age_sex_tissue[patient_id][0]
    obs_metrics['sex'] = age_sex_tissue[patient_id][1]
    obs_metrics['tissue'] = age_sex_tissue[patient_id][2]
    obs_metrics['sample_barcode'] = sample_name
    obs_metrics['uni_barcode'] = obs_metrics['dataset'] + '_' + obs_metrics.index.astype(str)

    sample.obs = obs_metrics
    sample.obs.set_index("uni_barcode", drop=False, inplace=True)
    print(sample)

    # save the anndata object
    output_path = write_directory / sample_h5ad
    sample.write_h5ad(output_path, compression="gzip")
# Out:
# AnnData object with n_obs × n_vars = 639 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 1052 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 768 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 445 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 1053 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 360 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 740 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 960 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 357 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 551 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'

# %%
sample.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.4, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, AL669831.5, FAM87B, LINC00115, FAM41C, AL645608.7, AL645608.3, AL645608.5, AL645608.1, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.8, HES4, ISG15, AL645608.2, AGRN, AL645608.9, RNF223, C1orf159, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20, AL391244.3, ANKRD65, AL391244.2, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, MORN1, RER1, PEX10, PLCH2, AL139246.1, AL139246.4, PANK4, HES5, ...]
#
# [33514 rows x 0 columns]

# %%
sample.obs
# Out:
#                                  cancer_type    dataset   age     sex  \
# uni_barcode
# GSE192906_A1_1_0904_AACGAGGT  ganglioneuroma  GSE192906  6.67  female
# GSE192906_A1_1_0904_AAGCACAT  ganglioneuroma  GSE192906  6.67  female
# GSE192906_A1_1_0904_ACACCGTG  ganglioneuroma  GSE192906  6.67  female
# GSE192906_A1_1_0904_ACCTCAGC  ganglioneuroma  GSE192906  6.67  female
# GSE192906_A1_1_0904_ACTGTTTG  ganglioneuroma  GSE192906  6.67  female
# ...                                      ...        ...   ...     ...
# GSE192906_F2_2_0904_TCTCACAC  ganglioneuroma  GSE192906  6.67  female
# GSE192906_F2_2_0904_TGGAGCTC  ganglioneuroma  GSE192906  6.67  female
# GSE192906_F2_2_0904_TGTACCAA  ganglioneuroma  GSE192906  6.67  female
# GSE192906_F2_2_0904_TTACGGGT  ganglioneuroma  GSE192906  6.67  female
# GSE192906_F2_2_0904_TTCCGTTC  ganglioneuroma  GSE192906  6.67  female
#
#                                       tissue  sample_barcode  \
# uni_barcode
# GSE192906_A1_1_0904_AACGAGGT  adrenal_ gland  GSM5768752_GN1
# GSE192906_A1_1_0904_AAGCACAT  adrenal_ gland  GSM5768752_GN1
# GSE192906_A1_1_0904_ACACCGTG  adrenal_ gland  GSM5768752_GN1
# GSE192906_A1_1_0904_ACCTCAGC  adrenal_ gland  GSM5768752_GN1
# GSE192906_A1_1_0904_ACTGTTTG  adrenal_ gland  GSM5768752_GN1
# ...                                      ...             ...
# GSE192906_F2_2_0904_TCTCACAC  adrenal_ gland  GSM5768752_GN1
# GSE192906_F2_2_0904_TGGAGCTC  adrenal_ gland  GSM5768752_GN1
# GSE192906_F2_2_0904_TGTACCAA  adrenal_ gland  GSM5768752_GN1
# GSE192906_F2_2_0904_TTACGGGT  adrenal_ gland  GSM5768752_GN1
# GSE192906_F2_2_0904_TTCCGTTC  adrenal_ gland  GSM5768752_GN1
#
#                                                uni_barcode
# uni_barcode
# GSE192906_A1_1_0904_AACGAGGT  GSE192906_A1_1_0904_AACGAGGT
# GSE192906_A1_1_0904_AAGCACAT  GSE192906_A1_1_0904_AAGCACAT
# GSE192906_A1_1_0904_ACACCGTG  GSE192906_A1_1_0904_ACACCGTG
# GSE192906_A1_1_0904_ACCTCAGC  GSE192906_A1_1_0904_ACCTCAGC
# GSE192906_A1_1_0904_ACTGTTTG  GSE192906_A1_1_0904_ACTGTTTG
# ...                                                    ...
# GSE192906_F2_2_0904_TCTCACAC  GSE192906_F2_2_0904_TCTCACAC
# GSE192906_F2_2_0904_TGGAGCTC  GSE192906_F2_2_0904_TGGAGCTC
# GSE192906_F2_2_0904_TGTACCAA  GSE192906_F2_2_0904_TGTACCAA
# GSE192906_F2_2_0904_TTACGGGT  GSE192906_F2_2_0904_TTACGGGT
# GSE192906_F2_2_0904_TTCCGTTC  GSE192906_F2_2_0904_TTCCGTTC
#
# [551 rows x 7 columns]

# %% [markdown]
# ### 3. Confirmation of created AnnData object

# %%
from pathlib import Path

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE192906')

# Loop through all files in the directory
for file in write_directory.iterdir():
    if '_uni.h5ad' in file.name:
        sample = anndata.read_h5ad(file)
        print(sample)
# Out:
# AnnData object with n_obs × n_vars = 551 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 740 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 1053 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 768 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 357 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 445 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 960 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 639 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 360 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 1052 × 33514
#     obs: 'cancer_type', 'dataset', 'age', 'sex', 'tissue', 'sample_barcode', 'uni_barcode'

# %%
sample.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.4, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, AL669831.5, FAM87B, LINC00115, FAM41C, AL645608.7, AL645608.3, AL645608.5, AL645608.1, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.8, HES4, ISG15, AL645608.2, AGRN, AL645608.9, RNF223, C1orf159, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20, AL391244.3, ANKRD65, AL391244.2, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, MORN1, RER1, PEX10, PLCH2, AL139246.1, AL139246.4, PANK4, HES5, ...]
#
# [33514 rows x 0 columns]

# %%
sample.obs
# Out:
#                                        cancer_type    dataset   age   sex  \
# uni_barcode
# GSE192906_K1_1_0316_AACGAGGT  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_K1_1_0316_AAGCACAT  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_K1_1_0316_ACACCGTG  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_K1_1_0316_ACCTCAGC  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_K1_1_0316_ACTGTTTG  ganglioneuroblastoma  GSE192906  2.42  male
# ...                                            ...        ...   ...   ...
# GSE192906_U2_2_0316_TCTCACAC  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_U2_2_0316_TGGAGCTC  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_U2_2_0316_TGTACCAA  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_U2_2_0316_TTACGGGT  ganglioneuroblastoma  GSE192906  2.42  male
# GSE192906_U2_2_0316_TTCCGTTC  ganglioneuroblastoma  GSE192906  2.42  male
#
#                                       tissue   sample_barcode  \
# uni_barcode
# GSE192906_K1_1_0316_AACGAGGT  adrenal_ gland  GSM5768749_GNB2
# GSE192906_K1_1_0316_AAGCACAT  adrenal_ gland  GSM5768749_GNB2
# GSE192906_K1_1_0316_ACACCGTG  adrenal_ gland  GSM5768749_GNB2
# GSE192906_K1_1_0316_ACCTCAGC  adrenal_ gland  GSM5768749_GNB2
# GSE192906_K1_1_0316_ACTGTTTG  adrenal_ gland  GSM5768749_GNB2
# ...                                      ...              ...
# GSE192906_U2_2_0316_TCTCACAC  adrenal_ gland  GSM5768749_GNB2
# GSE192906_U2_2_0316_TGGAGCTC  adrenal_ gland  GSM5768749_GNB2
# GSE192906_U2_2_0316_TGTACCAA  adrenal_ gland  GSM5768749_GNB2
# GSE192906_U2_2_0316_TTACGGGT  adrenal_ gland  GSM5768749_GNB2
# GSE192906_U2_2_0316_TTCCGTTC  adrenal_ gland  GSM5768749_GNB2
#
#                                                uni_barcode
# uni_barcode
# GSE192906_K1_1_0316_AACGAGGT  GSE192906_K1_1_0316_AACGAGGT
# GSE192906_K1_1_0316_AAGCACAT  GSE192906_K1_1_0316_AAGCACAT
# GSE192906_K1_1_0316_ACACCGTG  GSE192906_K1_1_0316_ACACCGTG
# GSE192906_K1_1_0316_ACCTCAGC  GSE192906_K1_1_0316_ACCTCAGC
# GSE192906_K1_1_0316_ACTGTTTG  GSE192906_K1_1_0316_ACTGTTTG
# ...                                                    ...
# GSE192906_U2_2_0316_TCTCACAC  GSE192906_U2_2_0316_TCTCACAC
# GSE192906_U2_2_0316_TGGAGCTC  GSE192906_U2_2_0316_TGGAGCTC
# GSE192906_U2_2_0316_TGTACCAA  GSE192906_U2_2_0316_TGTACCAA
# GSE192906_U2_2_0316_TTACGGGT  GSE192906_U2_2_0316_TTACGGGT
# GSE192906_U2_2_0316_TTCCGTTC  GSE192906_U2_2_0316_TTCCGTTC
#
# [1052 rows x 7 columns]

# %% [markdown]
# ### 4. Convert AnnData objects to SingleCellExperiment objects

# %%
from pathlib import Path

import anndata2ri
import rpy2.robjects as robjects
from rpy2.robjects import r
from rpy2.robjects.conversion import localconverter

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE192906')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample_name = file.stem
    if "_uni.h5ad" in file.name:
        sample_anndata = anndata.read_h5ad(file)
        sample_anndata.X = sample_anndata.X.astype('float32')
        sample_sce_file = sample_name + ".rds"

        with localconverter(anndata2ri.converter):
            sample_sce = anndata2ri.py2rpy(sample_anndata)
        # print(sample_sce)
        
        # Save the sce object in .rds file
        robjects.globalenv["sample_sce"] = sample_sce
        sample_sce_path = write_directory / sample_sce_file
        robjects.r("saveRDS(sample_sce, file='{}')".format(sample_sce_path))
