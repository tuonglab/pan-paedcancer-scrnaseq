# %% [markdown]
# ### 1. General info of dataset GSE231860
#
# This is the Jupyter Notebook for dataset GSE231860. Its dataset includes barcodes/features/matrix files for each sample.
#
# Thus, we need to simply incorparate these barcodes/features/matrix files and generate an AnnData object for each sample.
# In total, there are 19 samples.

# %%
# Environment setup
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as anndata
import scipy

# %% [markdown]
# ### 2. AnnData object of each sample
#
# <span style="color:red">**IMPORTANT:**</span> rename files to get rid of prefixes
#
# 1. `barcodes.tsv.gz`: cell barcodes, which go into `.obs`
# 2. `features.tsv.gz`: gene names, `.var`
# 3. `matrix.mtx.gz`: the expression matrix, `.X`

# %%
from pathlib import Path

# Specify directory paths
data_directory = Path('/scratch/user/s4543064/xiaohan-john-project/data/GSE231860')
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE231860')

# Loop through all files in the directory
for sample_directory in data_directory.iterdir():
    sample_name = sample_directory.stem
    sample_h5ad = sample_name + '_uni.h5ad'

    sample = sc.read_10x_mtx(
    sample_directory,
    var_names='gene_symbols',  
    cache=False
    )

    # Create an observation metric info to store related features
    obs_metrics = pd.DataFrame(index=sample.obs_names) ## Get the identifiers
    obs_metrics['cancer_type'] = 'high-grade_glioma'
    obs_metrics['dataset'] = 'GSE231860'
    obs_metrics['tissue'] = 'brain'
    obs_metrics['sample_barcode'] = sample_name
    obs_metrics['uni_barcode'] = obs_metrics['dataset'] + '_' + obs_metrics.index.astype(str)
    
    sample.obs = obs_metrics
    sample.obs.set_index("uni_barcode", drop=False, inplace=True)
    print(sample)

    # save the anndata object
    output_path = write_directory / sample_h5ad
    sample.write_h5ad(output_path, compression="gzip")
# Out:
# AnnData object with n_obs × n_vars = 641 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1018 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2092 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2790 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2769 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 234 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 582 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 948 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1906 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 705 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1725 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1508 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1190 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2189 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 486 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 4617 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 396 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1433 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 864 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'

# %%
sample.var
# Out:
#                     gene_ids    feature_types
# MIR1302-2HG  ENSG00000243485  Gene Expression
# FAM138A      ENSG00000237613  Gene Expression
# OR4F5        ENSG00000186092  Gene Expression
# AL627309.1   ENSG00000238009  Gene Expression
# AL627309.3   ENSG00000239945  Gene Expression
# ...                      ...              ...
# AC233755.2   ENSG00000277856  Gene Expression
# AC233755.1   ENSG00000275063  Gene Expression
# AC240274.1   ENSG00000271254  Gene Expression
# AC213203.1   ENSG00000277475  Gene Expression
# FAM231C      ENSG00000268674  Gene Expression
#
# [33538 rows x 2 columns]

# %%
sample.obs
# Out:
#                                     cancer_type    dataset tissue  \
# uni_barcode
# GSE231860_AAACCCACACACGCCA-1  high-grade_glioma  GSE231860  brain
# GSE231860_AAACGCTCAGGTGACA-1  high-grade_glioma  GSE231860  brain
# GSE231860_AAAGAACCACAGTGTT-1  high-grade_glioma  GSE231860  brain
# GSE231860_AAAGGGCCAGATCCAT-1  high-grade_glioma  GSE231860  brain
# GSE231860_AAAGGGCGTCATTCCC-1  high-grade_glioma  GSE231860  brain
# ...                                         ...        ...    ...
# GSE231860_TTTCACATCGGTCACG-1  high-grade_glioma  GSE231860  brain
# GSE231860_TTTCAGTTCTTTCTAG-1  high-grade_glioma  GSE231860  brain
# GSE231860_TTTCATGGTCCAGTTA-1  high-grade_glioma  GSE231860  brain
# GSE231860_TTTCCTCGTTCCATTT-1  high-grade_glioma  GSE231860  brain
# GSE231860_TTTGGAGAGTGGTTAA-1  high-grade_glioma  GSE231860  brain
#
#                                sample_barcode                   uni_barcode
# uni_barcode
# GSE231860_AAACCCACACACGCCA-1  GSM7305268_1187  GSE231860_AAACCCACACACGCCA-1
# GSE231860_AAACGCTCAGGTGACA-1  GSM7305268_1187  GSE231860_AAACGCTCAGGTGACA-1
# GSE231860_AAAGAACCACAGTGTT-1  GSM7305268_1187  GSE231860_AAAGAACCACAGTGTT-1
# GSE231860_AAAGGGCCAGATCCAT-1  GSM7305268_1187  GSE231860_AAAGGGCCAGATCCAT-1
# GSE231860_AAAGGGCGTCATTCCC-1  GSM7305268_1187  GSE231860_AAAGGGCGTCATTCCC-1
# ...                                       ...                           ...
# GSE231860_TTTCACATCGGTCACG-1  GSM7305268_1187  GSE231860_TTTCACATCGGTCACG-1
# GSE231860_TTTCAGTTCTTTCTAG-1  GSM7305268_1187  GSE231860_TTTCAGTTCTTTCTAG-1
# GSE231860_TTTCATGGTCCAGTTA-1  GSM7305268_1187  GSE231860_TTTCATGGTCCAGTTA-1
# GSE231860_TTTCCTCGTTCCATTT-1  GSM7305268_1187  GSE231860_TTTCCTCGTTCCATTT-1
# GSE231860_TTTGGAGAGTGGTTAA-1  GSM7305268_1187  GSE231860_TTTGGAGAGTGGTTAA-1
#
# [864 rows x 5 columns]

# %% [markdown]
# ### 3. Confirmation of created AnnData objects

# %%
from pathlib import Path

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE231860')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample = anndata.read_h5ad(file)
    print(sample)
# Out:
# AnnData object with n_obs × n_vars = 2092 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2769 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1508 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2189 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1018 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 705 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 582 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2790 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1725 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 948 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 641 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 4617 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 396 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1190 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 234 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1906 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 864 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1433 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 486 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'

# %% [markdown]
# ### 4. Convert AnnData objects to SingleCellExperiment objects

# %%
from pathlib import Path

import anndata2ri
import rpy2.robjects as robjects
from rpy2.robjects import r
from rpy2.robjects.conversion import localconverter

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE231860')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample_name = file.stem
    if "_uni.h5ad" in file.name:
        sample_anndata = anndata.read_h5ad(file)
        sample_sce_file = sample_name + ".rds"

        with localconverter(anndata2ri.converter):
            sample_sce = anndata2ri.py2rpy(sample_anndata)
        
        # Save the sce object in .rds file
        robjects.globalenv["sample_sce"] = sample_sce
        sample_sce_path = write_directory / sample_sce_file
        robjects.r("saveRDS(sample_sce, file='{}')".format(sample_sce_path))

# %%
print(sample_sce)
# Out:
# class: SingleCellExperiment
# dim: 33538 486
# metadata(0):
# assays(1): X
# rownames(33538): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(2): gene_ids feature_types
# colnames(486): GSE231860_AAAGAACGTACGTGTT-1
#   GSE231860_AACAAAGCAGACGGAT-1 ... GSE231860_TTTGTTGCAACCTAAC-1
#   GSE231860_TTTGTTGGTTCCATTT-1
# colData names(5): cancer_type dataset tissue sample_barcode uni_barcode
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
