# %% [markdown]
# ### 1. General info of dataset GSE154109
#
# This is the Jupyter Notebook for dataset GSE154109. Its dataset includes barcodes/features/matrix files for each sample.
#
# Thus, we need to simply incorparate these barcodes/features/matrix files and generate an AnnData object for each sample.
# In total, there are 19 samples:
#
# B-cell acute lymphoblastic leukemia patients (B-ALL: n=7)
#
# acute myeloid leukemia patients (AML: n=8)
#
# healthy donors (n=4)

# %%
# Environment setup
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as anndata
import scipy

# %% [markdown]
# ### 2. AnnData object of each sample
#
# <span style="color:red">**IMPORTANT:**</span> rename files to get rid of prefixes
#
# 1. `barcodes.tsv.gz`: cell barcodes, which go into `.obs`
# 2. `features.tsv.gz`: gene names, `.var`
# 3. `matrix.mtx.gz`: the expression matrix, `.X`

# %%
from pathlib import Path

# Specify directory paths
data_directory = Path('/scratch/user/s4543064/xiaohan-john-project/data/GSE154109')
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE154109')

# Loop through all files in the directory
for sample_directory in data_directory.iterdir():
    sample_name = sample_directory.stem
    sample_h5ad = sample_name + '_uni.h5ad'

    sample = sc.read_10x_mtx(
    sample_directory,
    var_names='gene_symbols',  
    cache=False
    )

    # Create an observation metric info to store related features
    obs_metrics = pd.DataFrame(index=sample.obs_names) ## Get the identifiers

    gsm_code = int(sample_name.split("_")[0][-2:])
    if gsm_code <= 12:
        cancer_type = 'healthy'
    elif gsm_code <= 20:
        cancer_type = 'acute_myeloid_leukemia'
    else:
        cancer_type = 'B-cell_acute_lymphoblastic_leukemia'
    
    obs_metrics['cancer_type'] = cancer_type

    obs_metrics['dataset'] = 'GSE154109'
    obs_metrics['tissue'] = 'bone_marrow'
    obs_metrics['sample_barcode'] = sample_name
    obs_metrics['uni_barcode'] = obs_metrics['dataset'] + '_' + obs_metrics.index.astype(str)
    
    sample.obs = obs_metrics
    sample.obs.set_index("uni_barcode", drop=False, inplace=True)
    print(sample)

    # save the anndata object
    output_path = write_directory / sample_h5ad
    sample.write_h5ad(output_path, compression="gzip")
# Out:
# AnnData object with n_obs × n_vars = 1171 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1766 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1472 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1304 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1675 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2341 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1669 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1211 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1563 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1687 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1173 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1999 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1022 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1402 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2137 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1586 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1687 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 518 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1947 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'

# %%
sample.obs
# Out:
#                                          cancer_type    dataset       tissue  \
# uni_barcode
# GSE154109_AAACCTGGTAGCGCTC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_AAACCTGGTCAATACC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_AAACCTGGTTCAGCGC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_AAACCTGTCGAACTGT-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_AAACCTGTCGTTGACA-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# ...                                              ...        ...          ...
# GSE154109_TTTGGTTGTTGAGTTC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_TTTGGTTTCCAAACAC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_TTTGTCAAGGGTCTCC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_TTTGTCACAGAAGCAC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
# GSE154109_TTTGTCATCTGGTTCC-1  acute_myeloid_leukemia  GSE154109  bone_marrow
#
#                                sample_barcode                   uni_barcode
# uni_barcode
# GSE154109_AAACCTGGTAGCGCTC-1  GSM4664016_1258  GSE154109_AAACCTGGTAGCGCTC-1
# GSE154109_AAACCTGGTCAATACC-1  GSM4664016_1258  GSE154109_AAACCTGGTCAATACC-1
# GSE154109_AAACCTGGTTCAGCGC-1  GSM4664016_1258  GSE154109_AAACCTGGTTCAGCGC-1
# GSE154109_AAACCTGTCGAACTGT-1  GSM4664016_1258  GSE154109_AAACCTGTCGAACTGT-1
# GSE154109_AAACCTGTCGTTGACA-1  GSM4664016_1258  GSE154109_AAACCTGTCGTTGACA-1
# ...                                       ...                           ...
# GSE154109_TTTGGTTGTTGAGTTC-1  GSM4664016_1258  GSE154109_TTTGGTTGTTGAGTTC-1
# GSE154109_TTTGGTTTCCAAACAC-1  GSM4664016_1258  GSE154109_TTTGGTTTCCAAACAC-1
# GSE154109_TTTGTCAAGGGTCTCC-1  GSM4664016_1258  GSE154109_TTTGTCAAGGGTCTCC-1
# GSE154109_TTTGTCACAGAAGCAC-1  GSM4664016_1258  GSE154109_TTTGTCACAGAAGCAC-1
# GSE154109_TTTGTCATCTGGTTCC-1  GSM4664016_1258  GSE154109_TTTGTCATCTGGTTCC-1
#
# [1947 rows x 5 columns]

# %% [markdown]
# ### 3. Confirmation of created AnnData objects

# %%
from pathlib import Path

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE154109')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample = anndata.read_h5ad(file)
    print(sample)
# Out:
# AnnData object with n_obs × n_vars = 1472 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1304 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1669 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2341 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1402 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 518 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1586 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1687 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1171 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1947 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 2137 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1687 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1563 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1675 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1211 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1766 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1022 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1999 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'
# AnnData object with n_obs × n_vars = 1173 × 33538
#     obs: 'cancer_type', 'dataset', 'tissue', 'sample_barcode', 'uni_barcode'
#     var: 'gene_ids', 'feature_types'

# %% [markdown]
# ### 4. Convert AnnData objects to SingleCellExperiment objects

# %%
from pathlib import Path

import anndata2ri
import rpy2.robjects as robjects
from rpy2.robjects import r
from rpy2.robjects.conversion import localconverter

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE154109')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample_name = file.stem
    if "_uni.h5ad" in file.name:
        sample_anndata = anndata.read_h5ad(file)
        sample_sce_file = sample_name + ".rds"

        with localconverter(anndata2ri.converter):
            sample_sce = anndata2ri.py2rpy(sample_anndata)
        
        # Save the sce object in .rds file
        robjects.globalenv["sample_sce"] = sample_sce
        sample_sce_path = write_directory / sample_sce_file
        robjects.r("saveRDS(sample_sce, file='{}')".format(sample_sce_path))

# %%
print(sample_sce)
# Out:
# class: SingleCellExperiment
# dim: 33538 1173
# metadata(0):
# assays(1): X
# rownames(33538): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(2): gene_ids feature_types
# colnames(1173): GSE154109_AAACCTGGTTATTCTC-1
#   GSE154109_AAACCTGTCTATCCCG-1 ... GSE154109_TTTGTCAAGAGTAAGG-1
#   GSE154109_TTTGTCACAGGGTATG-1
# colData names(5): cancer_type dataset tissue sample_barcode uni_barcode
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
