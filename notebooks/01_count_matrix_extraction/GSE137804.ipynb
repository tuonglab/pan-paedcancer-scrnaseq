# %% [markdown]
# ### 1. General info of dataset GSE137804
#
# This is the Jupyter Notebook for dataset GSE137804. Its dataset includes a xls file for each sample. As seen below, in the txt file, each row is a gene and each column is a cell.
#
# Thus, we need to transform this txt file and generate the AnnData object for each sample. In total, there are 22 samples.

# %%
# Environment setup
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as anndata
import scipy

# %%
# inspect one tumor dataset generated from 10x Genomics v2
tumor_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSM4088774_T10_gene_cell_exprs_table.xls.gz'
tumor_input = pd.read_csv(tumor_path, sep='\t', index_col=1) # the second column contains gene names and is the index

print(tumor_input.head()) 
print(tumor_input.shape)
# Out:
#                   Gene_ID  AAACCTGAGCTCAACT.1  AAACCTGAGGAGCGTT.1  \
# Symbol
# TSPAN6    ENSG00000000003                   1                   0
# DPM1      ENSG00000000419                   0                   1
# SCYL3     ENSG00000000457                   0                   0
# C1orf112  ENSG00000000460                   0                   0
# FGR       ENSG00000000938                   0                   0
#
#           AAACCTGCACCAGATT.1  AAACCTGGTCAGAATA.1  AAACCTGTCTTTAGTC.1  \
# Symbol
# TSPAN6                     0                   0                   0
# DPM1                       0                   1                   0
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
# FGR                        0                   0                   0
#
#           AAACGGGGTTTCCACC.1  AAAGATGAGTGGACGT.1  AAAGATGAGTGGCACA.1  \
# Symbol
# TSPAN6                     0                   0                   0
# DPM1                       0                   0                   0
# SCYL3                      1                   0                   1
# C1orf112                   0                   0                   0
# FGR                        0                   0                   0
#
#           AAAGATGCACCGTTGG.1  ...  TTTGCGCCATACAGCT.1  TTTGGTTAGGCAAAGA.1  \
# Symbol                        ...
# TSPAN6                     0  ...                   0                   0
# DPM1                       1  ...                   3                   0
# SCYL3                      0  ...                   0                   0
# C1orf112                   0  ...                   0                   0
# FGR                        0  ...                   0                   0
#
#           TTTGGTTCAGTTAACC.1  TTTGGTTTCCAGTAGT.1  TTTGGTTTCGCACTCT.1  \
# Symbol
# TSPAN6                     0                   2                   0
# DPM1                       1                   0                   0
# SCYL3                      0                   0                   0
# C1orf112                   1                   0                   0
# FGR                        0                   0                   0
#
#           TTTGGTTTCGGTGTCG.1  TTTGTCAAGACATAAC.1  TTTGTCAAGTATCGAA.1  \
# Symbol
# TSPAN6                     0                   0                   0
# DPM1                       2                   0                   1
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
# FGR                        0                   0                   0
#
#           TTTGTCATCCTTTCTC.1  TTTGTCATCTAAGCCA.1
# Symbol
# TSPAN6                     0                   0
# DPM1                       2                   0
# SCYL3                      0                   0
# C1orf112                   0                   0
# FGR                        0                   0
#
# [5 rows x 2390 columns]
# (18045, 2390)

# %%
# inspect one tumor dataset generated from 10x Genomics v3
tumor_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSM4654672_T200_gene_cell_exprs_table.xls.gz'
tumor_input = pd.read_csv(tumor_path, sep='\t', index_col=0) # the second column contains gene names and is the index

print(tumor_input.head()) 
print(tumor_input.shape)
# Out:
#              AAACCCAAGATACATG.1  AAACCCAAGATGGGCT.1  AAACCCAAGCGTTAGG.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCAAGGTAGCAC.1  AAACCCAAGGTCACAG.1  AAACCCAAGTTCATCG.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCACAACAAGAT.1  AAACCCACACCCAAGC.1  AAACCCACACCTATCC.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCACATGACTCA.1  ...  TTTGTTGCAGTAACGG.1  TTTGTTGCAGTCGCTG.1  \
# MIR1302-2HG                   0  ...                   0                   0
# FAM138A                       0  ...                   0                   0
# OR4F5                         0  ...                   0                   0
# AL627309.1                    0  ...                   0                   0
# AL627309.3                    0  ...                   0                   0
#
#              TTTGTTGGTACACTCA.1  TTTGTTGGTATCGCGC.1  TTTGTTGGTCGCGTCA.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGGTGGACCAA.1  TTTGTTGGTGTCCCTT.1  TTTGTTGGTTGCCTAA.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGTCGAACGCC.1  TTTGTTGTCTCGCAGG.1
# MIR1302-2HG                   0                   0
# FAM138A                       0                   0
# OR4F5                         0                   0
# AL627309.1                    0                   0
# AL627309.3                    0                   0
#
# [5 rows x 14466 columns]
# (33538, 14466)

# %%
# inspect the tumor annotation file
tumor_annotation_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSE137804_tumor_dataset_annotation.csv.gz'
tumor_annotation = pd.read_csv(tumor_annotation_path, sep=',', index_col=0) 

tumor_annotation
# Out:
#                         sample celltype
# cellname
# T10_AAGACCTAGTACTTGC.1     T10    tumor
# T10_TTTACTGCATGTAGTC.1     T10    tumor
# T10_AGAGCGAAGTTGAGTA.1     T10    tumor
# T10_CACCTTGAGTGTGGCA.1     T10    tumor
# T10_GAAATGAGTGGTACAG.1     T10    tumor
# ...                        ...      ...
# T230_TGTAACGTCCTAAGTG-1   T230    Tcell
# T230_TTCATGTGTGATAGTA-1   T230    Tcell
# T230_TTCGGTCAGTCGAAAT-1   T230    Tcell
# T230_TTCTTCCAGGGAGTTC-1   T230    Tcell
# T188_GCCTGTTCAAGATTGA-1   T188    Tcell
#
# [160847 rows x 2 columns]

# %%
# inspect the embryo dataset
embryo_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSM4654667_F366_gene_cell_exprs_table.xls.gz'
embryo_input = pd.read_csv(embryo_path, sep='\t', index_col=0) # the second column contains gene names and is the index

print(embryo_input.head())
# Out:
#              AAACCCAAGACTAAGT.1  AAACCCAAGAGGCGGA.1  AAACCCAAGGATACCG.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCAAGGTTGGAC.1  AAACCCAAGTCAGGGT.1  AAACCCAAGTCTACCA.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCAAGTCTCCTC.1  AAACCCACAAGCACCC.1  AAACCCACAAGTGCAG.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              AAACCCACACGCAAAG.1  ...  TTTGTTGGTACCTAGT.1  TTTGTTGGTGATGAAT.1  \
# MIR1302-2HG                   0  ...                   0                   0
# FAM138A                       0  ...                   0                   0
# OR4F5                         0  ...                   0                   0
# AL627309.1                    0  ...                   0                   0
# AL627309.3                    0  ...                   0                   0
#
#              TTTGTTGGTGTTCAGT.1  TTTGTTGTCAAGCCGC.1  TTTGTTGTCCAGTACA.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGTCCATGATG.1  TTTGTTGTCCCATTTA.1  TTTGTTGTCCGCATAA.1  \
# MIR1302-2HG                   0                   0                   0
# FAM138A                       0                   0                   0
# OR4F5                         0                   0                   0
# AL627309.1                    0                   0                   0
# AL627309.3                    0                   0                   0
#
#              TTTGTTGTCCTATGGA.1  TTTGTTGTCTTCCTAA.1
# MIR1302-2HG                   0                   0
# FAM138A                       0                   0
# OR4F5                         0                   0
# AL627309.1                    0                   0
# AL627309.3                    0                   0
#
# [5 rows x 23290 columns]

# %%
# inspect the embryo annotation file
embryo_annotation_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSE137804_Embryo_annotation.csv.gz'
embryo_annotation = pd.read_csv(embryo_annotation_path, sep=',', index_col=0) 

embryo_annotation
# Out:
#                    sample               annotation
# cell_id
# AAACCCAAGATTGAGT.1   F379               Mesenchyme
# AAACCCACAACCGTGC.1   F379             Motor neuron
# AAACCCACAAGAAATC.1   F379               Mesenchyme
# AAACCCACACGGTGCT.1   F379             Cadiomycytes
# AAACCCACATGAATCC.1   F379             Neural crest
# ...                   ...                      ...
# TTTGTTGTCCATGATG.1   F366               Mesenchyme
# TTTGTTGTCCCATTTA.1   F366               Mesenchyme
# TTTGTTGTCCGCATAA.1   F366               Mesenchyme
# TTTGTTGTCCTATGGA.1   F366  Gut endoderm epithelium
# TTTGTTGTCTTCCTAA.1   F366               Mesenchyme
#
# [36839 rows x 2 columns]

# %% [markdown]
# The count matrix file for embryos is different from the one for tumor samples, so need to process separately

# %%
# inspect the adrenal dataset
adrenal_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSM4088785_F2_gene_cell_exprs_table.xls.gz'
adrenal_input = pd.read_csv(adrenal_path, sep='\t', index_col=1) # the second column contains gene names and is the index

print(adrenal_input.head())
# Out:
#                   Gene_ID  AAACCTGAGACCTTTG.1  AAACCTGAGCGTTGCC.1  \
# Symbol
# TSPAN6    ENSG00000000003                   1                   0
# TNMD      ENSG00000000005                   0                   0
# DPM1      ENSG00000000419                   0                   0
# SCYL3     ENSG00000000457                   0                   0
# C1orf112  ENSG00000000460                   0                   0
#
#           AAACCTGAGGAATTAC.1  AAACCTGAGGTGCAAC.1  AAACCTGAGTACTTGC.1  \
# Symbol
# TSPAN6                     1                   0                   1
# TNMD                       0                   0                   0
# DPM1                       1                   0                   1
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
#
#           AAACCTGAGTGTTTGC.1  AAACCTGCAGCCTTTC.1  AAACCTGCAGCGAACA.1  \
# Symbol
# TSPAN6                     0                   0                   0
# TNMD                       0                   0                   0
# DPM1                       0                   0                   1
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
#
#           AAACCTGCAGTCGATT.1  ...  TTTGTCAGTGACAAAT.1  TTTGTCAGTGAGGGTT.1  \
# Symbol                        ...
# TSPAN6                     2  ...                   0                   0
# TNMD                       0  ...                   0                   0
# DPM1                       0  ...                   0                   0
# SCYL3                      0  ...                   0                   0
# C1orf112                   0  ...                   0                   0
#
#           TTTGTCAGTGATGCCC.1  TTTGTCAGTGGCTCCA.1  TTTGTCATCCAAGTAC.1  \
# Symbol
# TSPAN6                     0                   0                   0
# TNMD                       0                   0                   0
# DPM1                       1                   1                   0
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
#
#           TTTGTCATCCGCAGTG.1  TTTGTCATCCGCGCAA.1  TTTGTCATCTCATTCA.1  \
# Symbol
# TSPAN6                     0                   1                   0
# TNMD                       0                   0                   0
# DPM1                       0                   0                   0
# SCYL3                      0                   0                   0
# C1orf112                   0                   0                   0
#
#           TTTGTCATCTCTAAGG.1  TTTGTCATCTTTCCTC.1
# Symbol
# TSPAN6                     0                   0
# TNMD                       0                   0
# DPM1                       1                   1
# SCYL3                      0                   0
# C1orf112                   0                   0
#
# [5 rows x 8323 columns]

# %%
# inspect the adrenal annotation file
adrenal_annotation_path = '/scratch/user/s4543064/xiaohan-john-project/data/GSE137804/GSE137804_Adrenal_gland_annotation.csv.gz'
adrenal_annotation = pd.read_csv(adrenal_annotation_path, sep=',', index_col=0) 

adrenal_annotation
# Out:
#                      sample           annotation
# cell_id
# AAATGCCAGCTGTCTA.1_1     F2  Steroidogenic cells
# AAATGCCTCACAATGC.1_1     F2  Steroidogenic cells
# AACACGTGTCATGCCG.1_1     F2  Steroidogenic cells
# AACCGCGAGATCTGAA.1_1     F2  Steroidogenic cells
# AACGTTGTCGCTTAGA.1_1     F2  Steroidogenic cells
# ...                     ...                  ...
# TTGACTTGTGTTCGAT.1_4   F107                 SCPs
# TTGGCAAAGAGGTTAT.1_4   F107                 SCPs
# TTGTAGGAGGCGTACA.1_4   F107                 SCPs
# TTTGGTTAGATGCCTT.1_4   F107                 SCPs
# AACACGTCAAAGGCGT.1_1     F2       Capsular cells
#
# [49209 rows x 2 columns]

# %% [markdown]
# <span style="color:red">**PROBLEM:**</span> the cell names between the count matrix file and the annotation file are different

# %% [markdown]
# ### 2. Overall AnnData object of the dataset
#
# <span style="color:red">**IMPORTANT:**</span> transpose the DataFrame.values to match the AnnData.X
#
# 1. `DataFrame.columns`: cell barcodes, which go into `.obs`
# 2. `DataFrame.index`: gene names, `.var`
# 3. `DataFrame.values`: the transpose of the expression matrix, `.X`

# %%
# Load the metadata

embryo = ['F366', 'F379']
adrenal = ['F2', 'F7', 'F106', 'F107']
tumor = ['T10', 'T19', 'T27', 'T34', 'T40', 'T44', 'T69', 'T71', 'T75', 
         'T92', 'T162', 'T175', 'T188', 'T200', 'T214', 'T230'] # the downloaded sample file includes T175 instead of T174

v2 = adrenal + ['T10', 'T19', 'T27', 'T34', 'T40', 'T44', 'T69', 'T71', 'T75', 'T92']
v3 = embryo + ['T162', 'T175', 'T188', 'T200', 'T214', 'T230']

tissue_dict = { # can simplify this if have time later
    'GSM4088774': 'adrenal_gland', 
    'GSM4088775': 'adrenal_gland',
    'GSM4088776': 'adrenal_gland',
    'GSM4088777': 'adrenal_gland',
    'GSM4088778': 'adrenal_gland',
    'GSM4088779': 'adrenal_gland',
    'GSM4088780': 'adrenal_gland',
    'GSM4088781': 'adrenal_gland',
    'GSM4088782': 'adrenal_gland',
    'GSM4088783': 'adrenal_gland',
    'GSM4088785': 'adrenal_gland',
    'GSM4088786': 'adrenal_gland',
    'GSM4088787': 'adrenal_gland',
    'GSM4088788': 'adrenal_gland',
    'GSM4654667': 'embryo', 
    'GSM4654668': 'embryo',
    'GSM4654669': 'adrenal_gland',
    'GSM4654670': 'adrenal_gland',
    'GSM4654671': 'adrenal_gland',
    'GSM4654672': 'adrenal_gland',
    'GSM4654673': 'adrenal_gland',
    'GSM4654674': 'adrenal_gland',
}

sex_age_cancer_dict = {
    'T10': ['male', 3, 'ganglioneuroblastoma'],
    'T19': ['female', 2, 'ganglioneuroblastoma'],
    'T27': ['male', 3, 'neuroblastoma'],
    'T34': ['female', 3, 'neuroblastoma'],
    'T40': ['male', 0.17, 'neuroblastoma'],
    'T44': ['female', 0.17, 'neuroblastoma'],
    'T69': ['male', 2, 'neuroblastoma'],
    'T71': ['male', 0.01, 'neuroblastoma'],
    'T75': ['female', 0.75, 'neuroblastoma'],
    'T92': ['female', 3, 'neuroblastoma'],
    'T162': ['male', 2, 'neuroblastoma'],
    'T175': ['male', 0.06, 'neuroblastoma'],
    'T188': ['male', 0.25, 'neuroblastoma'],
    'T200': ['female', 2, 'neuroblastoma'],
    'T214': ['female', 0.25, 'neuroblastoma'],
    'T230': ['male', 4, 'neuroblastoma'],
}

adrenal_cell_suffix = {
    'F2': '_1',	
    'F7': '_2',
    'F106': '_3',	
    'F107': '_4',
}

# %%
import warnings
from pathlib import Path

warnings.filterwarnings("ignore", category=UserWarning)

# Specify directory paths
data_directory = Path('/scratch/user/s4543064/xiaohan-john-project/data/GSE137804')
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE137804')

# Loop through all files in the directory
for file in data_directory.iterdir():
    if 'annotation' not in file.stem:
        gsm, patient_id = file.stem.split('_')[:2]
        
        if patient_id in v3: # it is embryo sample
            input = pd.read_csv(file, sep='\t', index_col=0)
            var_df = pd.DataFrame(index=input.index)
        else:
            input = pd.read_csv(file, sep='\t', index_col=1)
            var_df = input.loc[:, ['Gene_ID']]
            input.drop(columns=['Gene_ID'], inplace=True)

        matrix = scipy.sparse.csr_matrix(input.values.T)
        obs_name = pd.DataFrame(index=input.columns)
        var_name = var_df
        var_name.rename_axis('gene_symbols', inplace=True)

        sample = anndata.AnnData(X=matrix, obs=obs_name, var=var_name)

        # Create an observation metric info to store related features
        obs_metrics = pd.DataFrame(index=sample.obs_names) ## Get the identifiers

        obs_metrics['dataset'] = 'GSE137804'
        obs_metrics['tissue'] = tissue_dict[gsm]

        # Load the metadata
        if patient_id in tumor: # it is embryo sample
            obs_metrics['sex'] = sex_age_cancer_dict[patient_id][0]
            obs_metrics['age'] = sex_age_cancer_dict[patient_id][1]
            obs_metrics['cancer_type'] = sex_age_cancer_dict[patient_id][2]
        else: 
            obs_metrics['sex'] = 'unknown'
            obs_metrics['age'] = 'unknown'
            obs_metrics['cancer_type'] = 'neuroblastoma'
            obs_metrics['disease_progression'] = 'healthy_donor'

        # Load the cell annotation
        if patient_id in tumor:
            obs_metrics['matched_cell_id'] = [patient_id + '_' + x for x in obs_metrics.index.tolist()]
            obs_metrics.set_index('matched_cell_id', drop=True, inplace=True)
            obs_metrics = obs_metrics.merge(tumor_annotation[['celltype']], how='left', left_index=True, right_index=True)
            obs_metrics.rename(columns={'celltype': 'cell_type_from_paper'}, inplace=True)
        elif patient_id in embryo:
            obs_metrics = obs_metrics.merge(embryo_annotation[['annotation']], how='left', left_index=True, right_index=True)
            obs_metrics.rename(columns={'annotation': 'cell_type_from_paper'}, inplace=True)
        else:
            obs_metrics['matched_cell_id'] = [x + adrenal_cell_suffix[patient_id] for x in obs_metrics.index.tolist()]
            obs_metrics.set_index('matched_cell_id', drop=True, inplace=True)
            obs_metrics = obs_metrics.merge(adrenal_annotation[['annotation']], how='left', left_index=True, right_index=True)
            obs_metrics.rename(columns={'annotation': 'cell_type_from_paper'}, inplace=True)

        obs_metrics['cell_type_from_paper'] = obs_metrics['cell_type_from_paper'].astype(str)
        obs_metrics['sample_barcode'] = file.stem.split('_gene_cell_exprs_table.xls')[0]
        obs_metrics['uni_barcode'] = obs_metrics['dataset'] + '_' + obs_metrics.index.astype(str)

        sample.obs = obs_metrics
        sample.obs.set_index("uni_barcode", drop=False, inplace=True)
        print(sample)

        # save the anndata object
        sample_h5ad = gsm + '_' + patient_id + '_uni.h5ad'
        output_path = write_directory / sample_h5ad
        sample.write_h5ad(output_path, compression="gzip")
# Out:
# AnnData object with n_obs × n_vars = 16053 × 17811
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 13569 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 23290 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 17809 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 6829 × 16444
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 17821 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 21109 × 23942
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 28642 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 4485 × 19671
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 14466 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 2572 × 19032
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 6916 × 17843
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 5704 × 18825
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 2389 × 18045
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 4242 × 22829
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 14528 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 6792 × 17625
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 12471 × 17048
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 25544 × 23557
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 10346 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 8322 × 19069
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 16428 × 16595
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'

# %%
sample.var
# Out:
#                         Gene_ID
# gene_symbols
# TSPAN6          ENSG00000000003
# DPM1            ENSG00000000419
# SCYL3           ENSG00000000457
# C1orf112        ENSG00000000460
# FGR             ENSG00000000938
# ...                         ...
# RP1-34B20.21    ENSG00000282988
# RP11-511P7.5    ENSG00000283013
# RP11-834C11.15  ENSG00000283073
# RP11-11M20.4    ENSG00000283078
# LLNLR-245B6.1   ENSG00000283103
#
# [16595 rows x 1 columns]

# %%
sample.obs
# Out:
#                                     dataset         tissue     sex   age  \
# uni_barcode
# GSE137804_T75_AAACCTGAGATCCCAT.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_AAACCTGAGCCTTGAT.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_AAACCTGAGCGATAGC.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_AAACCTGAGCGTTTAC.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_AAACCTGAGGAATGGA.1  GSE137804  adrenal_gland  female  0.75
# ...                                     ...            ...     ...   ...
# GSE137804_T75_TTTGTCATCCAACCAA.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_TTTGTCATCCGTTGTC.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_TTTGTCATCCTATTCA.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_TTTGTCATCTCACATT.1  GSE137804  adrenal_gland  female  0.75
# GSE137804_T75_TTTGTCATCTCTGAGA.1  GSE137804  adrenal_gland  female  0.75
#
#                                     cancer_type cell_type_from_paper  \
# uni_barcode
# GSE137804_T75_AAACCTGAGATCCCAT.1  neuroblastoma                tumor
# GSE137804_T75_AAACCTGAGCCTTGAT.1  neuroblastoma                tumor
# GSE137804_T75_AAACCTGAGCGATAGC.1  neuroblastoma                tumor
# GSE137804_T75_AAACCTGAGCGTTTAC.1  neuroblastoma                tumor
# GSE137804_T75_AAACCTGAGGAATGGA.1  neuroblastoma                tumor
# ...                                         ...                  ...
# GSE137804_T75_TTTGTCATCCAACCAA.1  neuroblastoma                  nan
# GSE137804_T75_TTTGTCATCCGTTGTC.1  neuroblastoma                tumor
# GSE137804_T75_TTTGTCATCCTATTCA.1  neuroblastoma                tumor
# GSE137804_T75_TTTGTCATCTCACATT.1  neuroblastoma                tumor
# GSE137804_T75_TTTGTCATCTCTGAGA.1  neuroblastoma                tumor
#
#                                   sample_barcode  \
# uni_barcode
# GSE137804_T75_AAACCTGAGATCCCAT.1  GSM4088782_T75
# GSE137804_T75_AAACCTGAGCCTTGAT.1  GSM4088782_T75
# GSE137804_T75_AAACCTGAGCGATAGC.1  GSM4088782_T75
# GSE137804_T75_AAACCTGAGCGTTTAC.1  GSM4088782_T75
# GSE137804_T75_AAACCTGAGGAATGGA.1  GSM4088782_T75
# ...                                          ...
# GSE137804_T75_TTTGTCATCCAACCAA.1  GSM4088782_T75
# GSE137804_T75_TTTGTCATCCGTTGTC.1  GSM4088782_T75
# GSE137804_T75_TTTGTCATCCTATTCA.1  GSM4088782_T75
# GSE137804_T75_TTTGTCATCTCACATT.1  GSM4088782_T75
# GSE137804_T75_TTTGTCATCTCTGAGA.1  GSM4088782_T75
#
#                                                        uni_barcode
# uni_barcode
# GSE137804_T75_AAACCTGAGATCCCAT.1  GSE137804_T75_AAACCTGAGATCCCAT.1
# GSE137804_T75_AAACCTGAGCCTTGAT.1  GSE137804_T75_AAACCTGAGCCTTGAT.1
# GSE137804_T75_AAACCTGAGCGATAGC.1  GSE137804_T75_AAACCTGAGCGATAGC.1
# GSE137804_T75_AAACCTGAGCGTTTAC.1  GSE137804_T75_AAACCTGAGCGTTTAC.1
# GSE137804_T75_AAACCTGAGGAATGGA.1  GSE137804_T75_AAACCTGAGGAATGGA.1
# ...                                                            ...
# GSE137804_T75_TTTGTCATCCAACCAA.1  GSE137804_T75_TTTGTCATCCAACCAA.1
# GSE137804_T75_TTTGTCATCCGTTGTC.1  GSE137804_T75_TTTGTCATCCGTTGTC.1
# GSE137804_T75_TTTGTCATCCTATTCA.1  GSE137804_T75_TTTGTCATCCTATTCA.1
# GSE137804_T75_TTTGTCATCTCACATT.1  GSE137804_T75_TTTGTCATCTCACATT.1
# GSE137804_T75_TTTGTCATCTCTGAGA.1  GSE137804_T75_TTTGTCATCTCTGAGA.1
#
# [16428 rows x 8 columns]

# %% [markdown]
# ### 3. Confirmation of created AnnData object

# %%
from pathlib import Path

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE137804')

# Loop through all files in the directory
for file in write_directory.iterdir():
    if '_uni.h5ad' in file.name:
        sample = anndata.read_h5ad(file)
        print(sample)
# Out:
# AnnData object with n_obs × n_vars = 12471 × 17048
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 23290 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 2389 × 18045
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 6829 × 16444
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 6916 × 17843
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 6792 × 17625
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 21109 × 23942
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 28642 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 25544 × 23557
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 4485 × 19671
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 5704 × 18825
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 16053 × 17811
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 17809 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 14528 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 16428 × 16595
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 10346 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 4242 × 22829
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 13569 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 17821 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
# AnnData object with n_obs × n_vars = 8322 × 19069
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 2572 × 19032
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'
# AnnData object with n_obs × n_vars = 14466 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'

# %%
eg_embryo = write_directory / 'GSM4654667_F366_uni.h5ad'
eg_adrenal = write_directory / 'GSM4088785_F2_uni.h5ad'
eg_tumor = write_directory / 'GSM4088774_T10_uni.h5ad'

# %%
eg_embryo_adata = anndata.read_h5ad(eg_embryo)
eg_embryo_adata
# Out:
# AnnData object with n_obs × n_vars = 23290 × 33538
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'

# %%
eg_embryo_adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [MIR1302-2HG, FAM138A, OR4F5, AL627309.1, AL627309.3, AL627309.2, AL627309.4, AL732372.1, OR4F29, AC114498.1, OR4F16, AL669831.2, AL669831.5, FAM87B, LINC00115, FAM41C, AL645608.7, AL645608.3, AL645608.5, AL645608.1, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.8, HES4, ISG15, AL645608.2, AGRN, AL645608.9, RNF223, C1orf159, LINC01342, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, PUSL1, INTS11, CPTP, TAS1R3, DVL1, MXRA8, AURKAIP1, CCNL2, MRPL20, AL391244.3, ANKRD65, AL391244.2, TMEM88B, LINC01770, VWA1, ATAD3C, ATAD3B, ATAD3A, TMEM240, SSU72, AL645728.1, FNDC10, AL691432.2, MIB2, MMP23B, CDK11B, FO704657.1, SLC35E2B, CDK11A, SLC35E2A, NADK, GNB1, AL109917.1, CALML6, TMEM52, CFAP74, AL391845.2, GABRD, AL391845.1, PRKCZ, AL590822.2, PRKCZ-AS1, FAAP20, AL590822.1, SKI, MORN1, RER1, PEX10, PLCH2, AL139246.1, AL139246.4, PANK4, HES5, ...]
#
# [33538 rows x 0 columns]

# %%
eg_embryo_adata.obs
# Out:
#                                 dataset  tissue      sex      age  \
# uni_barcode
# GSE137804_AAACCCAAGACTAAGT.1  GSE137804  embryo  unknown  unknown
# GSE137804_AAACCCAAGAGGCGGA.1  GSE137804  embryo  unknown  unknown
# GSE137804_AAACCCAAGGATACCG.1  GSE137804  embryo  unknown  unknown
# GSE137804_AAACCCAAGGTTGGAC.1  GSE137804  embryo  unknown  unknown
# GSE137804_AAACCCAAGTCAGGGT.1  GSE137804  embryo  unknown  unknown
# ...                                 ...     ...      ...      ...
# GSE137804_TTTGTTGTCCATGATG.1  GSE137804  embryo  unknown  unknown
# GSE137804_TTTGTTGTCCCATTTA.1  GSE137804  embryo  unknown  unknown
# GSE137804_TTTGTTGTCCGCATAA.1  GSE137804  embryo  unknown  unknown
# GSE137804_TTTGTTGTCCTATGGA.1  GSE137804  embryo  unknown  unknown
# GSE137804_TTTGTTGTCTTCCTAA.1  GSE137804  embryo  unknown  unknown
#
#                                 cancer_type disease_progression  \
# uni_barcode
# GSE137804_AAACCCAAGACTAAGT.1  neuroblastoma       healthy_donor
# GSE137804_AAACCCAAGAGGCGGA.1  neuroblastoma       healthy_donor
# GSE137804_AAACCCAAGGATACCG.1  neuroblastoma       healthy_donor
# GSE137804_AAACCCAAGGTTGGAC.1  neuroblastoma       healthy_donor
# GSE137804_AAACCCAAGTCAGGGT.1  neuroblastoma       healthy_donor
# ...                                     ...                 ...
# GSE137804_TTTGTTGTCCATGATG.1  neuroblastoma       healthy_donor
# GSE137804_TTTGTTGTCCCATTTA.1  neuroblastoma       healthy_donor
# GSE137804_TTTGTTGTCCGCATAA.1  neuroblastoma       healthy_donor
# GSE137804_TTTGTTGTCCTATGGA.1  neuroblastoma       healthy_donor
# GSE137804_TTTGTTGTCTTCCTAA.1  neuroblastoma       healthy_donor
#
#                                  cell_type_from_paper   sample_barcode  \
# uni_barcode
# GSE137804_AAACCCAAGACTAAGT.1  Gut endoderm epithelium  GSM4654667_F366
# GSE137804_AAACCCAAGAGGCGGA.1               Mesenchyme  GSM4654667_F366
# GSE137804_AAACCCAAGGATACCG.1                      nan  GSM4654667_F366
# GSE137804_AAACCCAAGGTTGGAC.1               Mesenchyme  GSM4654667_F366
# GSE137804_AAACCCAAGTCAGGGT.1               Mesenchyme  GSM4654667_F366
# ...                                               ...              ...
# GSE137804_TTTGTTGTCCATGATG.1               Mesenchyme  GSM4654667_F366
# GSE137804_TTTGTTGTCCCATTTA.1               Mesenchyme  GSM4654667_F366
# GSE137804_TTTGTTGTCCGCATAA.1               Mesenchyme  GSM4654667_F366
# GSE137804_TTTGTTGTCCTATGGA.1  Gut endoderm epithelium  GSM4654667_F366
# GSE137804_TTTGTTGTCTTCCTAA.1               Mesenchyme  GSM4654667_F366
#
#                                                uni_barcode
# uni_barcode
# GSE137804_AAACCCAAGACTAAGT.1  GSE137804_AAACCCAAGACTAAGT.1
# GSE137804_AAACCCAAGAGGCGGA.1  GSE137804_AAACCCAAGAGGCGGA.1
# GSE137804_AAACCCAAGGATACCG.1  GSE137804_AAACCCAAGGATACCG.1
# GSE137804_AAACCCAAGGTTGGAC.1  GSE137804_AAACCCAAGGTTGGAC.1
# GSE137804_AAACCCAAGTCAGGGT.1  GSE137804_AAACCCAAGTCAGGGT.1
# ...                                                    ...
# GSE137804_TTTGTTGTCCATGATG.1  GSE137804_TTTGTTGTCCATGATG.1
# GSE137804_TTTGTTGTCCCATTTA.1  GSE137804_TTTGTTGTCCCATTTA.1
# GSE137804_TTTGTTGTCCGCATAA.1  GSE137804_TTTGTTGTCCGCATAA.1
# GSE137804_TTTGTTGTCCTATGGA.1  GSE137804_TTTGTTGTCCTATGGA.1
# GSE137804_TTTGTTGTCTTCCTAA.1  GSE137804_TTTGTTGTCTTCCTAA.1
#
# [23290 rows x 9 columns]

# %%
eg_adrenal_adata = anndata.read_h5ad(eg_adrenal)
eg_adrenal_adata
# Out:
# AnnData object with n_obs × n_vars = 8322 × 19069
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'disease_progression', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'

# %%
eg_adrenal_adata.var
# Out:
#                         Gene_ID
# gene_symbols
# TSPAN6          ENSG00000000003
# TNMD            ENSG00000000005
# DPM1            ENSG00000000419
# SCYL3           ENSG00000000457
# C1orf112        ENSG00000000460
# ...                         ...
# RP11-511P7.5    ENSG00000283013
# RP11-736N17.11  ENSG00000283071
# RP11-834C11.15  ENSG00000283073
# RP11-11M20.4    ENSG00000283078
# LLNLR-245B6.1   ENSG00000283103
#
# [19069 rows x 1 columns]

# %%
eg_adrenal_adata.obs
# Out:
#                                   dataset         tissue      sex      age  \
# uni_barcode
# GSE137804_AAACCTGAGACCTTTG.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_AAACCTGAGCGTTGCC.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_AAACCTGAGGAATTAC.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_AAACCTGAGGTGCAAC.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_AAACCTGAGTACTTGC.1_1  GSE137804  adrenal_gland  unknown  unknown
# ...                                   ...            ...      ...      ...
# GSE137804_TTTGTCATCCGCAGTG.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_TTTGTCATCCGCGCAA.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_TTTGTCATCTCATTCA.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_TTTGTCATCTCTAAGG.1_1  GSE137804  adrenal_gland  unknown  unknown
# GSE137804_TTTGTCATCTTTCCTC.1_1  GSE137804  adrenal_gland  unknown  unknown
#
#                                   cancer_type disease_progression  \
# uni_barcode
# GSE137804_AAACCTGAGACCTTTG.1_1  neuroblastoma       healthy_donor
# GSE137804_AAACCTGAGCGTTGCC.1_1  neuroblastoma       healthy_donor
# GSE137804_AAACCTGAGGAATTAC.1_1  neuroblastoma       healthy_donor
# GSE137804_AAACCTGAGGTGCAAC.1_1  neuroblastoma       healthy_donor
# GSE137804_AAACCTGAGTACTTGC.1_1  neuroblastoma       healthy_donor
# ...                                       ...                 ...
# GSE137804_TTTGTCATCCGCAGTG.1_1  neuroblastoma       healthy_donor
# GSE137804_TTTGTCATCCGCGCAA.1_1  neuroblastoma       healthy_donor
# GSE137804_TTTGTCATCTCATTCA.1_1  neuroblastoma       healthy_donor
# GSE137804_TTTGTCATCTCTAAGG.1_1  neuroblastoma       healthy_donor
# GSE137804_TTTGTCATCTTTCCTC.1_1  neuroblastoma       healthy_donor
#
#                                cell_type_from_paper sample_barcode  \
# uni_barcode
# GSE137804_AAACCTGAGACCTTTG.1_1                 SCPs  GSM4088785_F2
# GSE137804_AAACCTGAGCGTTGCC.1_1     Chromaffin cells  GSM4088785_F2
# GSE137804_AAACCTGAGGAATTAC.1_1       Capsular cells  GSM4088785_F2
# GSE137804_AAACCTGAGGTGCAAC.1_1                  nan  GSM4088785_F2
# GSE137804_AAACCTGAGTACTTGC.1_1       Capsular cells  GSM4088785_F2
# ...                                             ...            ...
# GSE137804_TTTGTCATCCGCAGTG.1_1  Steroidogenic cells  GSM4088785_F2
# GSE137804_TTTGTCATCCGCGCAA.1_1       Capsular cells  GSM4088785_F2
# GSE137804_TTTGTCATCTCATTCA.1_1  Steroidogenic cells  GSM4088785_F2
# GSE137804_TTTGTCATCTCTAAGG.1_1     Chromaffin cells  GSM4088785_F2
# GSE137804_TTTGTCATCTTTCCTC.1_1  Steroidogenic cells  GSM4088785_F2
#
#                                                    uni_barcode
# uni_barcode
# GSE137804_AAACCTGAGACCTTTG.1_1  GSE137804_AAACCTGAGACCTTTG.1_1
# GSE137804_AAACCTGAGCGTTGCC.1_1  GSE137804_AAACCTGAGCGTTGCC.1_1
# GSE137804_AAACCTGAGGAATTAC.1_1  GSE137804_AAACCTGAGGAATTAC.1_1
# GSE137804_AAACCTGAGGTGCAAC.1_1  GSE137804_AAACCTGAGGTGCAAC.1_1
# GSE137804_AAACCTGAGTACTTGC.1_1  GSE137804_AAACCTGAGTACTTGC.1_1
# ...                                                        ...
# GSE137804_TTTGTCATCCGCAGTG.1_1  GSE137804_TTTGTCATCCGCAGTG.1_1
# GSE137804_TTTGTCATCCGCGCAA.1_1  GSE137804_TTTGTCATCCGCGCAA.1_1
# GSE137804_TTTGTCATCTCATTCA.1_1  GSE137804_TTTGTCATCTCATTCA.1_1
# GSE137804_TTTGTCATCTCTAAGG.1_1  GSE137804_TTTGTCATCTCTAAGG.1_1
# GSE137804_TTTGTCATCTTTCCTC.1_1  GSE137804_TTTGTCATCTTTCCTC.1_1
#
# [8322 rows x 9 columns]

# %%
eg_tumor_adata = anndata.read_h5ad(eg_tumor)
eg_tumor_adata
# Out:
# AnnData object with n_obs × n_vars = 2389 × 18045
#     obs: 'dataset', 'tissue', 'sex', 'age', 'cancer_type', 'cell_type_from_paper', 'sample_barcode', 'uni_barcode'
#     var: 'Gene_ID'

# %%
eg_tumor_adata.var
# Out:
#                        Gene_ID
# gene_symbols
# TSPAN6         ENSG00000000003
# DPM1           ENSG00000000419
# SCYL3          ENSG00000000457
# C1orf112       ENSG00000000460
# FGR            ENSG00000000938
# ...                        ...
# PRNCR1         ENSG00000282961
# RP1-34B20.21   ENSG00000282988
# RP11-511P7.5   ENSG00000283013
# RP11-11M20.4   ENSG00000283078
# LLNLR-245B6.1  ENSG00000283103
#
# [18045 rows x 1 columns]

# %%
eg_tumor_adata.obs
# Out:
#                                     dataset         tissue   sex  age  \
# uni_barcode
# GSE137804_T10_AAACCTGAGCTCAACT.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_AAACCTGAGGAGCGTT.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_AAACCTGCACCAGATT.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_AAACCTGGTCAGAATA.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_AAACCTGTCTTTAGTC.1  GSE137804  adrenal_gland  male    3
# ...                                     ...            ...   ...  ...
# GSE137804_T10_TTTGGTTTCGGTGTCG.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_TTTGTCAAGACATAAC.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_TTTGTCAAGTATCGAA.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_TTTGTCATCCTTTCTC.1  GSE137804  adrenal_gland  male    3
# GSE137804_T10_TTTGTCATCTAAGCCA.1  GSE137804  adrenal_gland  male    3
#
#                                            cancer_type cell_type_from_paper  \
# uni_barcode
# GSE137804_T10_AAACCTGAGCTCAACT.1  ganglioneuroblastoma                tumor
# GSE137804_T10_AAACCTGAGGAGCGTT.1  ganglioneuroblastoma                tumor
# GSE137804_T10_AAACCTGCACCAGATT.1  ganglioneuroblastoma                Tcell
# GSE137804_T10_AAACCTGGTCAGAATA.1  ganglioneuroblastoma                tumor
# GSE137804_T10_AAACCTGTCTTTAGTC.1  ganglioneuroblastoma                tumor
# ...                                                ...                  ...
# GSE137804_T10_TTTGGTTTCGGTGTCG.1  ganglioneuroblastoma                tumor
# GSE137804_T10_TTTGTCAAGACATAAC.1  ganglioneuroblastoma                tumor
# GSE137804_T10_TTTGTCAAGTATCGAA.1  ganglioneuroblastoma                tumor
# GSE137804_T10_TTTGTCATCCTTTCTC.1  ganglioneuroblastoma                tumor
# GSE137804_T10_TTTGTCATCTAAGCCA.1  ganglioneuroblastoma                  nan
#
#                                   sample_barcode  \
# uni_barcode
# GSE137804_T10_AAACCTGAGCTCAACT.1  GSM4088774_T10
# GSE137804_T10_AAACCTGAGGAGCGTT.1  GSM4088774_T10
# GSE137804_T10_AAACCTGCACCAGATT.1  GSM4088774_T10
# GSE137804_T10_AAACCTGGTCAGAATA.1  GSM4088774_T10
# GSE137804_T10_AAACCTGTCTTTAGTC.1  GSM4088774_T10
# ...                                          ...
# GSE137804_T10_TTTGGTTTCGGTGTCG.1  GSM4088774_T10
# GSE137804_T10_TTTGTCAAGACATAAC.1  GSM4088774_T10
# GSE137804_T10_TTTGTCAAGTATCGAA.1  GSM4088774_T10
# GSE137804_T10_TTTGTCATCCTTTCTC.1  GSM4088774_T10
# GSE137804_T10_TTTGTCATCTAAGCCA.1  GSM4088774_T10
#
#                                                        uni_barcode
# uni_barcode
# GSE137804_T10_AAACCTGAGCTCAACT.1  GSE137804_T10_AAACCTGAGCTCAACT.1
# GSE137804_T10_AAACCTGAGGAGCGTT.1  GSE137804_T10_AAACCTGAGGAGCGTT.1
# GSE137804_T10_AAACCTGCACCAGATT.1  GSE137804_T10_AAACCTGCACCAGATT.1
# GSE137804_T10_AAACCTGGTCAGAATA.1  GSE137804_T10_AAACCTGGTCAGAATA.1
# GSE137804_T10_AAACCTGTCTTTAGTC.1  GSE137804_T10_AAACCTGTCTTTAGTC.1
# ...                                                            ...
# GSE137804_T10_TTTGGTTTCGGTGTCG.1  GSE137804_T10_TTTGGTTTCGGTGTCG.1
# GSE137804_T10_TTTGTCAAGACATAAC.1  GSE137804_T10_TTTGTCAAGACATAAC.1
# GSE137804_T10_TTTGTCAAGTATCGAA.1  GSE137804_T10_TTTGTCAAGTATCGAA.1
# GSE137804_T10_TTTGTCATCCTTTCTC.1  GSE137804_T10_TTTGTCATCCTTTCTC.1
# GSE137804_T10_TTTGTCATCTAAGCCA.1  GSE137804_T10_TTTGTCATCTAAGCCA.1
#
# [2389 rows x 8 columns]

# %% [markdown]
# ### 4. Convert AnnData objects to SingleCellExperiment objects

# %%
from pathlib import Path

import anndata2ri
import rpy2.robjects as robjects
from rpy2.robjects import r
from rpy2.robjects.conversion import localconverter

# Specify directory paths
write_directory = Path('/scratch/user/s4543064/xiaohan-john-project/write/GSE137804')

# Loop through all files in the directory
for file in write_directory.iterdir():
    sample_name = file.stem
    if "_uni.h5ad" in file.name:
        sample_anndata = anndata.read_h5ad(file)
        sample_anndata.X = sample_anndata.X.astype('float32')
        sample_sce_file = sample_name + ".rds"

        with localconverter(anndata2ri.converter):
            sample_sce = anndata2ri.py2rpy(sample_anndata)
        # print(sample_sce)
        
        # Save the sce object in .rds file
        robjects.globalenv["sample_sce"] = sample_sce
        sample_sce_path = write_directory / sample_sce_file
        robjects.r("saveRDS(sample_sce, file='{}')".format(sample_sce_path))

# %%
print(sample_sce)
# Out:
# class: SingleCellExperiment
# dim: 33538 14466
# metadata(0):
# assays(1): X
# rownames(33538): MIR1302-2HG FAM138A ... AC213203.1 FAM231C
# rowData names(0):
# colnames(14466): GSE137804_T200_AAACCCAAGATACATG.1
#   GSE137804_T200_AAACCCAAGATGGGCT.1 ...
#   GSE137804_T200_TTTGTTGTCGAACGCC.1 GSE137804_T200_TTTGTTGTCTCGCAGG.1
# colData names(8): dataset tissue ... sample_barcode uni_barcode
# reducedDimNames(0):
# mainExpName: NULL
# altExpNames(0):
