# %% [markdown]
# #### This is the Jupyter Notebook to plot figures for the manuscript

# %% [markdown]
# #### 1. Plot the pie chars

# %%
import matplotlib
import matplotlib.pyplot as plt

FONTTYPE = 42

# set the font so no weird lines and boxes are made during export
matplotlib.rcParams["pdf.fonttype"] = FONTTYPE
matplotlib.rcParams["ps.fonttype"] = FONTTYPE

palette = [
    "#4E79A7",
    "#F28E2B",
    "#E15759",
    "#76B7B2",
    "#59A14F",
    "#EDC948",
    "#B07AA1",
    "#FF9DA7",
    "#9C755F",
    "#BAB0AC",
]

# %%
repo_dict = {
    "Gene Expression Omnibus (GEO)": 27,
    "European Genome-phenome Archive (EGA)": 7,
    "EGA & GEO": 2,
    "EGA & European Nucleotide Archive (ENA)": 2,
    "Genome Sequence Archive (GSA)": 2,
    "BioProject": 1,
    "Synapse": 1,
    "Unknown": 5,
}

# Extract labels and values
repositories = list(repo_dict.keys())
dataset_counts = list(repo_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for repo, count in zip(repositories, dataset_counts)]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(repositories)-1] + [palette[-1]],
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Repository')
plt.legend(repositories, loc='upper right', bbox_to_anchor=(2.1, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2B_repo.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
accessibility_dict = {
    "Accessible": 31,
    "Restricted": 16,
}

# Extract labels and values
accessibility = list(accessibility_dict.keys())
dataset_counts = list(accessibility_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(accessibility)],
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Dataset Accessibility')
plt.legend(accessibility, loc='upper right', bbox_to_anchor=(1.5, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2C_accessibility.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
global_dict = {
    "Leukemia": 77681,
    "Lymphoma": 37446,
    "CNS tumour":	30871,
    "Kidney cancer*": 13184,
    "Thyroid cancer": 10636,
    "Others":	105895,
}

# Extract labels and values
cancers = list(global_dict.keys())
dataset_counts = list(global_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(cancers)-1] + [palette[-1]],
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Global Incidence in 2022')
plt.legend(cancers, loc='upper right', bbox_to_anchor=(1.6, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2D_global_incidence.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
patientnum_palette = [
    "#4E79A7",
    "#E15759",
    "#76B7B2",
    "#EDC948",
    "#B07AA1",
    "#FF9DA7",
    "#9C755F",
    "#D7B5A6"
]

# %%
patientnum_dict = {
    "Leukemia": 122,
    "CNS tumour":	169,
    "Kidney cancer*": 7,
    "Neuroblastic tumour": 196,
    "Retinoblastoma": 83,
    "Sarcoma": 41,
    "Bone cancer":	32,
    "Pancreatic cancer": 7,
}

# Extract labels and values
cancers = list(patientnum_dict.keys())
dataset_counts = list(patientnum_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=patientnum_palette,
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Patient Number')
plt.legend(cancers, loc='upper right', bbox_to_anchor=(1.6, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2D_patient_number.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
seq_platform_dict = {
    "10x Genomics": 35,
    "10x Genomics & CEL-seq2": 2,
    "10x Genomics & Smart-seq2": 1,
    "Smart-seq/Smart-seq2":	4,
    "CEL-seq2":	2,
    "Singleron": 2,
    "SORT-seq":	1,
}

# Extract labels and values
platforms = list(seq_platform_dict.keys())
dataset_counts = list(seq_platform_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(platforms)],
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Sequencing platform')
plt.legend(platforms, loc='upper right', bbox_to_anchor=(1.7, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2E_seq_platform.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
multiplexed_dict = {
    "Yes": 23,
    "No": 24,
}

# Extract labels and values
factors = list(multiplexed_dict.keys())
dataset_counts = list(multiplexed_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(factors)],
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Multiplexed Sequencing')
plt.legend(factors, loc='upper right', bbox_to_anchor=(1.4, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig2F_multiplexed.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
control_dict = {
    "Internal & External": 1,
    "Internal & Matched": 4,
    "Internal":	7,
    "External & Matched": 3,
    "Matched": 3,
    "External":	8,
    "Not Included":	21,
}

# Extract labels and values
factors = list(control_dict.keys())
dataset_counts = list(control_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(factors)-1] + [palette[-1]],
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Healthy Control Inclusion')
plt.legend(factors, loc='upper right', bbox_to_anchor=(1.6, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig3A_control_inclusion.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
cell_metadata_dict = {
    "Annotated": 13,
    "Unannotated": 34,
}

# Extract labels and values
factors = list(cell_metadata_dict.keys())
dataset_counts = list(cell_metadata_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(factors)-1] + [palette[-1]],
    wedgeprops={'edgecolor': 'black'},
)
plt.title('Cell Metadata')
plt.legend(factors, loc='upper right', bbox_to_anchor=(1.5, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig3C_cell_metadata.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
patient_metadata_dict = {
    "Provided": 39,
    "Not provided": 8,
}

# Extract labels and values
factors = list(patient_metadata_dict.keys())
dataset_counts = list(patient_metadata_dict.values())
total_datasets = sum(dataset_counts)

# Create a list of labels showing the exact count and percentage
labels_with_counts = [f'{count} ({count/total_datasets*100:.1f}%)' for count in dataset_counts]

# Plot the pie chart
plt.figure(figsize=(7, 5))
plt.pie(
    dataset_counts,
    labels=labels_with_counts,
    startangle=90,
    counterclock=False,
    colors=palette[:len(factors)-1] + [palette[-1]],
    wedgeprops={'edgecolor': 'black'},
)
plt.title("Patient Metadata")
plt.legend(factors, loc='upper right', bbox_to_anchor=(1.5, 1))
plt.savefig("/scratch/user/s4543064/Xiaohan_Summer_Research/figures/Fig3D_patient_metadata.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 2. Plot the UMAP

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("/scratch/user/s4543064/Xiaohan_Summer_Research/write/all_cancer_meta_anndata_scVI_pca_clean.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 1300958 × 559
#     obs: 'cancer_type', 'dataset', 'tissue', 'uni_barcode', 'disease_progression', 'sample_barcode', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'gmm_pct_count_clusters_keep', 'filter_rna', 'cell_type_from_paper', 'malignant_from_paper', 'age_months', 'age', 'sex', 'recurrent', 'cancer_subtype', 'metastatic', '_scvi_batch', '_scvi_labels', 'major_cancer_type', 'major_cancer_type_order', 'cancer_type_order'
#     var: 'gene_ids', 'feature_types', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'cancer_type_colors', 'cancer_type_order_colors', 'hvg', 'major_cancer_type_order_colors', 'neighbors', 'pca', 'sample_barcode_colors', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
# Update the major cancer type names
cancer_names = {
    'leukemia': 'Leukemia', 
    'healthy_donor': 'Healthy donor', 
    'brain_tumor': 'CNS tumour', 
    'bone_cancer': 'Bone cancer', 
    'sarcoma': 'Sarcoma', 
    'neural_tumor': 'Peripheral neuroblastic tumour', 
    'retinoblastoma': 'Retinoblastoma', 
    'kidney_cancer': 'Kidney cancer'
}

adata.obs['major_cancer_type'] = adata.obs['major_cancer_type'].replace(cancer_names)
adata.obs['major_cancer_type_order'] = adata.obs['major_cancer_type_order'].replace(cancer_names)
adata.obs["major_cancer_type_order"].value_counts()
# Out:
# /scratch/temp/12004550/ipykernel_4117787/355221939.py:13: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata.obs['major_cancer_type'] = adata.obs['major_cancer_type'].replace(cancer_names)
# /scratch/temp/12004550/ipykernel_4117787/355221939.py:14: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   adata.obs['major_cancer_type_order'] = adata.obs['major_cancer_type_order'].replace(cancer_names)
# major_cancer_type_order
# Leukemia                          419590
# Peripheral neuroblastic tumour    306795
# CNS tumour                        135544
# ...

# %%
import pandas as pd

# Match the order with the pie chart
desired_order = [
    'Leukemia', 
    'CNS tumour', 
    'Kidney cancer', 
    'Peripheral neuroblastic tumour', 
    'Retinoblastoma', 
    'Sarcoma', 
    'Bone cancer', 
    'Healthy donor'
]

# Convert the column to a categorical type with the specified order
adata.obs['major_cancer_type_order'] = pd.Categorical(
    adata.obs['major_cancer_type_order'], 
    categories=desired_order, 
    ordered=True
)

# Check if it has been ordered
print(adata.obs['major_cancer_type_order'])
# Out:
# GSE235923_AAACCTGAGCTAGTGG-1_GSM7512002_Sample4D                      Leukemia
# GSE235923_AAACCTGAGGATGCGT-1_GSM7512002_Sample4D                      Leukemia
# GSE235923_AAACCTGAGGGTGTTG-1_GSM7512002_Sample4D                      Leukemia
# GSE235923_AAACCTGAGTTCGCGC-1_GSM7512002_Sample4D                      Leukemia
# GSE235923_AAACCTGCAATGAATG-1_GSM7512002_Sample4D                      Leukemia
#                                                                      ...
# GSE223373_TTCACGCAGCGAGTAAACGTATCA_GSM6946667_WT-RBG-N_matrix    Healthy donor
# GSE223373_TTCACGCAGTCGTAGAAAGACGGA_GSM6946667_WT-RBG-N_matrix    Healthy donor
# GSE223373_TTCACGCAGTGTTCTAGTACGCAA_GSM6946667_WT-RBG-N_matrix    Healthy donor
# GSE223373_TTCACGCATAGGATGATCTTCACA_GSM6946667_WT-RBG-N_matrix    Healthy donor
# GSE223373_TTCACGCATTCACGCACGAACTTA_GSM6946667_WT-RBG-N_matrix    Healthy donor
# Name: major_cancer_type_order, Length: 1300958, dtype: category
# ...

# %%
patientnum_palette = [
    "#4E79A7",
    "#E15759",
    "#76B7B2",
    "#EDC948",
    "#B07AA1",
    "#FF9DA7",
    "#9C755F",
    "#D7B5A6"
]

# %%
sc.settings.figdir = '/scratch/user/s4543064/Xiaohan_Summer_Research/figures/'
sc.settings.vector_friendly = False

sc.pl.umap(adata, color='major_cancer_type_order', frameon=False, palette=patientnum_palette,
           save='Fig3B_umap.pdf')
# Out:
# /home/s4543064/miniforge3/envs/scvi_env/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# WARNING: saving figure to file /scratch/user/s4543064/Xiaohan_Summer_Research/figures/umapFig3B_umap.pdf
# /home/s4543064/miniforge3/envs/scvi_env/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
