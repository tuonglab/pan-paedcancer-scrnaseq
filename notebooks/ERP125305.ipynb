# %% [markdown]
# ### 1. General info of dataset ERP125305
#
# This is the Jupyter Notebook for dataset ERP125305.

# %%
# Environment setup
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as anndata
import scipy

# %%
adata = sc.read_h5ad('/scratch/user/s4543064/xiaohan-john-project/data/ERP125305/download')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 103228 × 33712
#     obs: 'cell.labels', 'lanes', 'orig.ident', 'sequencing.type', 'broad_fig1_cell.labels', 'stage', 'sex'
#     var: 'gene_ids-1', 'feature_types-1', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'broad_fig1_cell.labels_colors', 'cell.labels_colors', 'neighbors', 'orig.ident_colors', 'pca', 'sequencing.type_colors', 'sex_colors'
#     obsm: 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.var
# Out:
#                     gene_ids-1  feature_types-1  highly_variable  \
# RP11-34P13.3   ENSG00000243485  Gene Expression            False
# RP11-34P13.7   ENSG00000238009  Gene Expression            False
# RP11-34P13.8   ENSG00000239945  Gene Expression            False
# RP11-34P13.9   ENSG00000241599  Gene Expression            False
# FO538757.3     ENSG00000279928  Gene Expression            False
# ...                        ...              ...              ...
# TRBJ2-2        ENSG00000211765  Gene Expression            False
# MAGEA2         ENSG00000268606  Gene Expression            False
# CTD-2308B18.4  ENSG00000248600  Gene Expression            False
# CTB-58E17.2    ENSG00000274996  Gene Expression            False
# RP5-1077H22.1  ENSG00000278343  Gene Expression            False
#
#                       means  dispersions  dispersions_norm
# RP11-34P13.3   6.261492e-05    -0.327390         -1.251869
# RP11-34P13.7   1.273112e-03     0.765471          0.258501
# ...

# %%
adata.obs
# Out:
#                                                              cell.labels  \
# index
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AAAC...       early erythroid
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...  erythroid macrophage
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AACT...            neutrophil
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AAGA...         CD14 monocyte
# F21_boneMarrow_CD45+_FCAImmP7179367_3prime_AAGG...          DC precursor
# ...                                                                  ...
# TTTGGTTAGATGATTG-1-WSSS_F_BON8710643                       mid erythroid
# TTTGGTTGTGGATCGA-1-WSSS_F_BON8710643                          neutrophil
# TTTGTTGAGTTGGCGA-1-WSSS_F_BON8710643                      late erythroid
# TTTGTTGTCAATGTCG-1-WSSS_F_BON8710643                    pro B progenitor
# TTTGTTGTCACCCTCA-1-WSSS_F_BON8710643                    pro B progenitor
#
#                                                                 lanes  \
# index
# ...
